# %%
from icrawler.builtin import BaiduImageCrawler, BingImageCrawler, GoogleImageCrawler

# %%
bing_crawler = BingImageCrawler(storage={'root_dir': '/Users/xmh/AI_mask/no_mask'})

# %%
bing_crawler.crawl(keyword='person', filters=None, offset=0, max_num=600)
# Out:
# 2020-09-15 19:10:14,896 - INFO - icrawler.crawler - start crawling...
# 2020-09-15 19:10:14,900 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2020-09-15 19:10:14,905 - INFO - icrawler.crawler - starting 1 parser threads...
# 2020-09-15 19:10:14,915 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2020-09-15 19:10:15,333 - INFO - parser - parsing result page https://www.bing.com/images/async?q=person&first=0
# 2020-09-15 19:10:15,398 - INFO - downloader - skip downloading file 000001.jpg
# 2020-09-15 19:10:15,400 - INFO - downloader - skip downloading file 000002.jpg
# 2020-09-15 19:10:15,402 - INFO - downloader - skip downloading file 000003.jpg
# 2020-09-15 19:10:15,560 - INFO - downloader - image #4	https://cdn.pixabay.com/photo/2013/03/14/06/08/person-93459_640.jpg
# 2020-09-15 19:10:15,563 - INFO - downloader - skip downloading file 000005.jpg
# 2020-09-15 19:10:15,565 - INFO - downloader - skip downloading file 000006.jpg
# ...

# %%
google_crawler = GoogleImageCrawler(storage={'root_dir': '/Users/xmh/AI_mask/mask'})

# %%
google_crawler.crawl(keyword='person with mask', filters=None, offset=0, max_num=500)
# Out:
# 2020-09-15 15:24:21,277 - INFO - icrawler.crawler - start crawling...
# 2020-09-15 15:24:21,280 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2020-09-15 15:24:21,284 - INFO - feeder - thread feeder-001 exit
# 2020-09-15 15:24:21,284 - INFO - icrawler.crawler - starting 1 parser threads...
# 2020-09-15 15:24:21,291 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2020-09-15 15:24:21,999 - INFO - parser - parsing result page https://www.google.com/search?q=person+with+mask&ijn=0&start=0&tbs=&tbm=isch
# 2020-09-15 15:24:22,227 - INFO - downloader - image #1	https://wchstv.com/resources/media/8ed6dbc3-2523-455b-a6aa-380cd7df61e0-large16x9_FaceMasksSBG.jpg
# 2020-09-15 15:24:22,470 - ERROR - downloader - Response status code 400, file https://cnet1.cbsistatic.com/img/ToryVWaKoj5du8xlH4Q2pCpgLOw\u003d/940x0/2020/03/06/a13e8ffc-c31f-4f4e-8153-20edc74d365c/gettyimages-1209334802.jpg
# ...

# %%
baidu_crawler = BaiduImageCrawler(storage={'root_dir': '/Users/xmh/AI_mask/no_mask'})

# %%
baidu_crawler.crawl(keyword='人像', filters=None, offset=0, max_num=200)
# Out:
# 2020-09-15 21:40:34,853 - INFO - icrawler.crawler - start crawling...
# 2020-09-15 21:40:34,856 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2020-09-15 21:40:34,861 - INFO - icrawler.crawler - starting 1 parser threads...
# 2020-09-15 21:40:34,865 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2020-09-15 21:40:36,316 - INFO - parser - parsing result page http://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&word=人像&pn=0&rn=30
# 2020-09-15 21:40:43,524 - ERROR - downloader - Exception caught when downloading file http://pic1.16xx8.com/allimg/150617/16xx8.jpg, error: HTTPConnectionPool(host='pic1.16xx8.com', port=80): Read timed out., remaining retry times: 2
# 2020-09-15 21:41:20,747 - ERROR - downloader - Exception caught when downloading file http://pic1.16xx8.com/allimg/150617/16xx8.jpg, error: HTTPConnectionPool(host='pic1.16xx8.com', port=80): Read timed out., remaining retry times: 1
# ...
